# %%
from pyspark.sql import SparkSession
# 1. Create the Spark Session
spark = SparkSession.builder.appName("ColabSparkExercise").getOrCreate()
# 2. Get the Spark Context for RDDs
sc = spark.sparkContext
from pyspark.sql.functions import avg

# %%
#Question 2(Python Even list For First 6 Numbers)
even_num = [x for x in range(2, 14, 2)]
print(f"Python Even Num List: {even_num}")
# Out:
# Python Even Num List: [2, 4, 6, 8, 10, 12]

# %%
#Question 2
#Using parallelize to make list RDD
even_num_rdd = sc.parallelize(even_num)

# %%
from os import read
#Question 3 (Clients dataset)
#Filtering out married people and calculating average
clients_df = (
    spark.read.csv(
        "/content/Clients.csv",
        header=True,
        inferSchema=True
    )
)

clients_df.show()
clients_df= clients_df.filter(clients_df.marital ==1)
# Out:
# +---------------------------------+
# |age;marital;income;gender;custcat|
# +---------------------------------+
# |                  44;1;64.000;0;1|
# |                 33;1;136.000;0;4|
# |                 52;1;116.000;1;3|
# |                  33;0;33.000;1;1|
# |                  30;1;30.000;0;3|
# |                  39;0;78.000;1;3|
# |                  22;1;19.000;1;2|
# |                  35;0;76.000;0;4|
# |                 59;1;166.000;0;3|
# |                  41;1;72.000;0;2|
# |                 33;0;125.000;1;1|
# |                  35;0;80.000;1;3|
# |                  38;1;37.000;1;1|
# |                 54;1;115.000;1;4|
# |                  46;0;25.000;1;1|
# |                  38;1;75.000;0;2|
# |                 57;0;162.000;0;3|
# |                  48;0;49.000;1;3|
# |                  24;0;20.000;0;1|
# |                  29;1;77.000;0;4|
# +---------------------------------+
# only showing top 20 rows
# ...

# %%
#Question 4(Using the Cars Dataset)
Cars_df = (
    spark.read.csv(
        "/Cars.csv",
        header=True,
        inferSchema=True
    )
)
Cars_df.show()
# Out:
# +------+---------+--------------------+--------+----------+----------+-----------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+---------+
# |car_ID|symboling|             CarName|fueltype|aspiration|doornumber|    carbody|drivewheel|enginelocation|wheelbase|carlength|carwidth|carheight|curbweight|enginetype|cylindernumber|enginesize|fuelsystem|boreratio|stroke|compressionratio|horsepower|peakrpm|citympg|highwaympg|    price|
# +------+---------+--------------------+--------+----------+----------+-----------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+---------+
# ...

# %%
cars_df.show(5)
# Out:
# +------+---------+--------------------+--------+----------+----------+-----------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+-------+
# |car_ID|symboling|             CarName|fueltype|aspiration|doornumber|    carbody|drivewheel|enginelocation|wheelbase|carlength|carwidth|carheight|curbweight|enginetype|cylindernumber|enginesize|fuelsystem|boreratio|stroke|compressionratio|horsepower|peakrpm|citympg|highwaympg|  price|
# +------+---------+--------------------+--------+----------+----------+-----------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+-------+
# ...

# %%
cars_df.count()
# Out:
# 205

# %%
cars_more_11k_df = cars_df.filter(cars_df.price > 11000)
cars_more_11k_df.show()
# Out:
# +------+---------+--------------------+--------+----------+----------+-----------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+---------+
# |car_ID|symboling|             CarName|fueltype|aspiration|doornumber|    carbody|drivewheel|enginelocation|wheelbase|carlength|carwidth|carheight|curbweight|enginetype|cylindernumber|enginesize|fuelsystem|boreratio|stroke|compressionratio|horsepower|peakrpm|citympg|highwaympg|    price|
# +------+---------+--------------------+--------+----------+----------+-----------+----------+--------------+---------+---------+--------+---------+----------+----------+--------------+----------+----------+---------+------+----------------+----------+-------+-------+----------+---------+
# ...
